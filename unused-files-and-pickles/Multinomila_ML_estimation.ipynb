# %% [markdown]
# Classification without training/test split
# =======
# Code that's given:
#
# Training Data: a dictionary whose key: word, value: frequency in topic corpus
# Test Data: handpicked examples that appear in training data
#
# Run script as following:
# no arguments. will generated confusion matrix average for all ten splits

# %%
# %run multinomialClassification.py 2 dump# result running from per split
# Out:
# Elapsed Time for predicting :  19.18168354034424
# Elapsed Time for predicting :  16.763949871063232
# Precision:  0.8514166666666667  +/-  0.0042006943870428505

# %%
# %run multinomialClassification.py
# Out:
# Elapsed Time for predicting :  19.241851091384888
# Elapsed Time for predicting :  20.194369077682495
# Elapsed Time for predicting :  26.407655239105225
# Elapsed Time for predicting :  17.134798288345337
# Elapsed Time for predicting :  16.869754314422607
# Elapsed Time for predicting :  16.951760292053223
# Elapsed Time for predicting :  16.96989870071411
# Elapsed Time for predicting :  16.9902446269989
# Elapsed Time for predicting :  18.30091691017151
# Elapsed Time for predicting :  17.604565382003784
# Precision:  0.8515  +/-  0.0035335691745190024

# %% [markdown]
# Automating Test/Train Split
# =======
# Samy has already done the data splitting for 20_newsgroups.
# Train Data:
# 1. a Dok Matrix whose
#  - row: document in some topic
#  - column: corresponds to count of word in documents
#  Note that the columns do /not/ have any semantic meaning (they are matched with test data columns)
# 2. a label vector:
#  a list of topics corresponding to each row
#
# Test Data:
# 1. same Dok Matrix
# 2. label vector

# %%
# %run splitData.py
